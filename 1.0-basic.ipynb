# %%
1+1
# Out:
# 2

# %%
##Basic syntax

name="krishna"
Name="rishna"

print(name)
print(Name)
# Out:
# krishna
# rishna

# %%
age=23
if age>23:
    print(1+1)
    print('Age is 23')
else:
    print('Age is not >23')
# Out:
# Age is not >23

# %%
age=24
if age>23:
    
    print("IF BLOCK",age)

print("OUTSIDE IF BLOCK",age)
# Out:
# IF BLOCK 24
# OUTSIDE IF BLOCK 24

# %%
## Single line syntax
print("Jagannath")
# Out:
# Jagannath

# %%
##Line continuation & here the back slash is used to continue to the next line don't forget to use the 
# mathematical symbols after number and then use the back slash to continue.


total=6+6+7+8+8+\
6+4+8

print(total)
# Out:
# 53

# %%
#Multiple statements in a  single line

x=6;y=5;z=x+y

print(z)
# Out:
# 11

# %%
##Understand the semantics in python
#Variable semantics

age=23 ##age is a integer
name="rishna" ##name is a string

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
#Type inference


variable=3
print(type(variable))
variable="rishna"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
##Remember to give a single quotation or else it will show an error

age=23
if age<20:
    print('age')
else:
    print('age is not less than 20')
# Out:
# age is not less than 20

# %%
##Indentation (python uses indentation to define blocks of code)

if True:
    print("Today is Monday")
    if False:
        print("today is not monday")
    print("today is Monday")
print("Today is saturday outside the if block")
# Out:
# Today is Monday
# today is Monday
# Today is saturday outside the if block

# %%
## Declaring and aassigning the variable

age=23
gender="girl"
name="Rish"

# printing the variables

print("age:",age)
print("gender:",gender)
print("name:", name)
# Out:
# age: 23
# gender: girl
# name: Rish

# %%
## naming conventions
## variable name should be descriptive & variable is a case sensitive
# They must start with letter don't give number in starting & '_' & contains letter, number and underscore


# Valid variable

first_name="Royal"
middle_name="Rishna"
last_name="Patra"

# %%
# Invalid variable name

2age=5
first-name=rish
# Out:
#   Cell In[23], line 3
#     2age=5
#     ^
# SyntaxError: invalid decimal literal

# %%
## case sensitive

name="Royal"
Name="Rishna"
name==Name
# Out:
# False

# %%
name="royal"
Name="patra"

# %%
##uderstand the variable types
# python is dynamically typed, type of variabe is determined in a run type 
# give point in float don't forget

age=23 #int
height=5.3 #float
name="rish" #string
is_employee=True # Boolean 

print(type(age))
print(type(name))
print(type(is_employee))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'bool'>

# %%
#Type checking and conversion

type(height)
# Out:
# float

# %%
##can we convert 1 datatype to another? and alsso u can convert in many type conversions


age=23
print(type(age))

#Type conversion

age_str=str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 23
# <class 'str'>

# %%
##different type convertions

age='23'
int(age)
# Out:
# 23

# %%
#numerical can be converted and string cannot be converted in float type also

age='23'
print(type(int(age)))
# Out:
# <class 'int'>

# %%
height=5.1
type(height)
# Out:
# float

# %%
#The float can be converted into integer

int(height)
# Out:
# 5

# %%
float(int(height))
# Out:
# 5.0

# %%
#Dynamic type
#python allows the type  of a variable to change as pgm executes

var=10 #

# %%
#Integer 

age=23
type(age)
# Out:
# int

# %%
#Floating point data type

height=5.1
print(height)
print(type(height))
# Out:
# 5.1
# <class 'float'>

# %%
#string datatype example

name='rish'
print('name')
print(type(name))
# Out:
# name
# <class 'str'>

# %%
#boolean data type

is_true=True
type(is_true)
# Out:
# bool

# %%
a=10
b=10
type(a==b)
# Out:
# bool

# %%
result='hello' + str(5)
print(result)
# Out:
# hello5

# %%
##Arithmetic operators


a=3
b=7

result=3+7
print(result)
# Out:
# 10

# %%
a=3
b=7

add_result=a+b 
sub_result=a-b
mult_result=a*b
div_result=a/b
floor_div_result=a//b     ## Floor division(here the FV will remove the decimsl & give the value)
modular_result=a%b     ## here 3 is divided by 7
exponent_result=a**b    ##Exponential

print(add_result)
print(sub_result)
print(mult_result)
print(div_result)
print(floor_div_result)
print(modular_result)
print(exponent_result)
# Out:
# 10
# -4
# 21
# 0.42857142857142855
# 0
# 3
# 2187

# %%
## Comparision Operator
##Equal too operator
a=8
b=8

a==b




str1="Rish"
str2="Rish"    ##if u give small letters and then execute then this will be not equal too)
str1==str2
# Out:
# True

# %%
## Not equal too !=

str1="rish"
str2="Rish"
str1!=str2
# Out:
# True

# %%
##Greater than >

num1=45
num2=55

num1>num2
# Out:
# False

# %%
## less than <

num1<num2
# Out:
# True

# %%
##greater than or equal to >=

number1=33
number2=33

number1>=number2 ## if u add print(number1>=number2) then also the result will be shown
# Out:
# True

# %%
##lesser than or equal to <=

number1=33
number2=33

number1<=number2  ## the condition will be true because the one condition is crt which is 33 is equal to 33
# Out:
# True

# %%
# Logical operator 

# AND , OR , NOT

##In AND operator the boolean is true then u'll get true
x=True
y=True

result =x and y
print(result)
# Out:
# True

# %%
##In OR operator u will get true/ false when both the value is true or flase
x=True
y=True

result =x or y 
print(result)
# Out:
# True

# %%
x=False
y=True

result =x or y 
print(result)
# Out:
# True

# %%
# NOT operator is a reverse of boolean variable


x=True
not x
# Out:
# False

# %%
x=False
not x
# Out:
# True

# %%
#Simple calculator

num1=4
num2=5

num1= float(input("Enter first number: "))
num2= float(input("Enter second number: "))

# Performing arithmetic operations

addition = num1+num2
subtraction = num1-num2
multiplication=num1*num2
division=num1 / num2
floor_division=num1 // num2
modulus=num1 % num2
exponentiation=num1**num2

# Displaying results

print("Addition:", addition)
print("Subtraction:", subtraction)
print("Multiplication:", multiplication)
print("Division:", division)
print("Floor Division:", floor_division)
print("Modulus:", modulus)
print("Exponentiation:", exponentiation)

# %%
### Executes only if the condition is true
## IF Statement


age=20
if age>=18:
    print("You are eligible to vote in the election")
# Out:
# You are eligible to vote in the election

# %%
age>=18
# Out:
# True

# %%
## ELSE statement
#This executes only the block of code if the condition in the if statement is flase

age=16
if age>=18:
    print("You are eligible to vote in the election")
else:
    print("you are a minor")
# Out:
# you are a minor

# %%
## ELIF statement allows u to check a multiple condition it is "elseif" statement

age=20
if age<20:
    print("You are a child")
elif age<=20:
    print("You are a citizen of the country")
else: 
     print("you are an adult")
# Out:
# You are a citizen of the country

# %%
##Nested condition statement

# You can place one or more if,else,elif, statement inside another if,else,elif statement in an nested condition statement
# Number even,odd,negative

num=int(input("Enter the number"))

if num>=0:
    print("The number is positive")
    if num%2==0:
        print("The number is even")
    else:
        print("The number is odd")
else:
    print("The number is zero or negative")
